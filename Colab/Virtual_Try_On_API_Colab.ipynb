# %% [markdown]
# # Virtual Fitting Room CatVTON FastAPI
#
# Run this notebook on a **GPU runtime**. It runs the real CatVTON try-on model and exposes a `/tryon` FastAPI endpoint for the ASP.NET site.

# %%
# !if [ ! -d /content/CatVTON ]; then git clone --depth 1 https://github.com/Zheng-Chong/CatVTON /content/CatVTON; fi
# !pip install -q fastapi uvicorn python-multipart huggingface_hub diffusers transformers accelerate safetensors opencv-python-headless pillow scipy tqdm
# !nvidia-smi

# %% [markdown]
# Upload `Colab/colab_tryon_api.py` from this project when Colab asks for it.

# %%
from google.colab import files
files.upload()

# %% [markdown]
# Run the API. Keep this cell running. Copy the printed URL ending with `/tryon`, then paste it into the Upload page's `Colab FastAPI URL` field.

# %%
# !python /content/colab_tryon_api.py --tunnel --width 576 --height 768 --steps 12 --guidance-scale 2.0
