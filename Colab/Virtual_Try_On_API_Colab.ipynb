# %% [markdown]
# # Virtual Fitting Room Colab API
#
# Run this notebook on a **GPU runtime**. It exposes a `/tryon` API for the ASP.NET site.

# %%
# !git clone https://github.com/Zheng-Chong/CatVTON /content/CatVTON
# !pip install -q fastapi uvicorn python-multipart huggingface_hub diffusers transformers accelerate safetensors opencv-python pillow scipy tqdm

# %% [markdown]
# Upload `colab_tryon_api.py` from this folder when Colab asks for it.

# %%
from google.colab import files
files.upload()

# %% [markdown]
# Run the API. Keep this cell running. Copy the printed URL ending with `/tryon` into `VirtualTryOn:ApiUrl` in `appsettings.json`.

# %%
# !python /content/colab_tryon_api.py --tunnel --width 576 --height 768 --steps 20
